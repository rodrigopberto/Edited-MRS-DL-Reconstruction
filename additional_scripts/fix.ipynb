# %%
import pandas as pd

# %%
df = pd.read_csv("eval/fit_ranges/acc_ref_df.csv")

df["range"]=df.apply(lambda x: x["range"].replace(".mat",""),axis=1)

# %%
df.to_csv("eval/fit_ranges/acc_ref_df.csv",index=False)

# %%
import h5py

# %%
with h5py.File("data/split_ranges/test_data_range_split_1.h5") as hf:
    print(hf["ranges"][(
        
    )])
# Out:
# [b'1-80' b'11-90' b'21-100' b'31-110' b'41-120' b'51-130' b'61-140'
#  b'71-150' b'81-160' b'91-170' b'101-180' b'111-190' b'121-200' b'131-210'
#  b'141-220' b'151-230' b'161-240' b'171-250' b'181-260' b'191-270'
#  b'201-280' b'211-290' b'221-300' b'231-310' b'241-320' b'1-80' b'11-90'
#  b'21-100' b'31-110' b'41-120' b'51-130' b'61-140' b'71-150' b'81-160'
#  b'91-170' b'101-180' b'111-190' b'121-200' b'131-210' b'141-220'
#  b'151-230' b'161-240' b'171-250' b'181-260' b'191-270' b'201-280'
#  b'211-290' b'221-300' b'231-310' b'241-320' b'1-80' b'11-90' b'21-100'
#  b'31-110' b'41-120' b'51-130' b'61-140' b'71-150' b'81-160' b'91-170'
#  b'101-180' b'111-190' b'121-200' b'131-210' b'141-220' b'151-230'
#  b'161-240' b'171-250' b'181-260' b'191-270' b'201-280' b'211-290'
#  b'221-300' b'231-310' b'241-320' b'1-80' b'11-90' b'21-100' b'31-110'
#  b'41-120' b'51-130' b'61-140' b'71-150' b'81-160' b'91-170' b'101-180'
# ...
